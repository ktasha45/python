# %%
import random
print(random.random()) # 0.0 <= x < 1.0 의 소수
print(random.randint(1,10)) # 1 <= x <= 10 의 정수

numbers = [1, 2, 3, 4, 5, 6, 7]
print(random.sample(numbers,  3))
# Out:
# 0.18400191509592467
# 2
# [7, 5, 6]

# %%
import pandas as pd
dataframe = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
print(dataframe.head())
# Out:
#       School  Women  Men  Gap
# 0        MIT     94  152   58
# 1   Stanford     96  151   55
# 2    Harvard    112  165   53
# 3     U.Penn     92  141   49
# 4  Princeton     90  137   47

# %%
from sklearn.datasets import *
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([1, 2, 3], [1, 2, 3])
plt.show()

# %%
from ipywidgets import interact
def f(n):
    result = n * n
    print("{} * {} = {}".format(n, n, result))
interact(f, n=(0, 10))
# Out:
# interactive(children=(IntSlider(value=5, description='n', max=10), Output()), _dom_classes=('widget-interact',…
# <function __main__.f(n)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples = 500, centers = 4, cluster_std = 0.40, random_state = 0)
plt.scatter(X[:, 0], X[:, 1], s = 50);
plt.show()

kmeans = KMeans(n_clusters = 4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c = y_kmeans, s = 50, cmap = 'viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'black', s = 200, alpha = 0.5);
plt.show()

# %%
def coordinate_generator(n):
    pairs = []
    for i in range(n):
        x = random.random()
        y = random.random()
        pairs.append([x,y])
    return pairs
coordinate_generator(10)
# Out:
# [[0.38377478569017853, 0.7724985943165079],
#  [0.7812907311709626, 0.23988138774144496],
#  [0.969473163301488, 0.9583951120316504],
#  [0.0527739441350491, 0.054969003429024554],
#  [0.7209696860944629, 0.8231393876401936],
#  [0.29708694649180634, 0.3733769057826889],
#  [0.31034459827079364, 0.287249160733725],
#  [0.003737340091912844, 0.07700879100266445],
#  [0.40020041737827416, 0.5940756295906012],
#  [0.01762927777410983, 0.10700367709732928]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

data = coordinate_generator(100)
X = np.array(data)

plt.scatter(X[:, 0], X[:, 1])
plt.show()

kmeans = KMeans(n_clusters = 4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c = y_kmeans, s = 50, cmap = 'viridis')
plt.show()

# %%
digit = load_digits()
digit_d = pd.DataFrame(digit['data'][0:1600])

def Image_display(i):
   plt.imshow(digit['images'][i],cmap = 'Greys_r')
   plt.show()

# %%
Image_display(0)

# %%
train_x = digit['data'][:1600]
train_y = digit['target'][:1600]
KNN = KNeighborsClassifier(20)
KNN.fit(train_x,train_y)
test = np.array(digit['data'][1725])
test1 = test.reshape(1,-1)

Image_display(1725)
print(KNN.predict(test1))
# Out:
# [6]

# %% [markdown]
# 모델을 만들고
# * model = [여러 library의 모델들]
#
# 학습시켜서
# * .fit (학습데이터)
#
# 사용하자
# * .predict (테스트데이터)
